# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import time
import tensorflow_probability as tfp
tfd = tfp.distributions
tfb = tfp.bijectors

print(tf.__version__)
# Mac OS jupyter kernel dies without
import os
os.environ['KMP_DUPLICATE_LIB_OK']='True'
# Out:
# 2.1.0

# %% [markdown]
# ### Define density network model parameterized by Real NVP.

# %%
from tensorflow.keras import Model

class DensityNetwork(Model):
    def __init__(self, D, num_layers, num_units):
        super(DensityNetwork, self).__init__()
        self.D = D
        self.num_masked = D//2
        self.shift_and_log_scale_fn = tfb.real_nvp_default_template(
                                          hidden_layers=num_layers*[num_units])
        self.a = tf.Variable(tf.ones((2,2)))
        self.b = tf.Variable(tf.zeros((1,2)))        
        
    def __call__(self, N):
        """self.nvp = tfb.RealNVP(
            num_masked=self.num_masked,
            shift_and_log_scale_fn=self.shift_and_log_scale_fn
        )"""
        q0 = tfd.MultivariateNormalDiag(loc=D*[0.])
        x = q0.sample(N)
        log_q0 = q0.log_prob(x)
        self.bij = tfb.Affine(scale_identity_multiplier=2., shift=self.b)
        ldj = self.bij.forward_log_det_jacobian(x, event_ndims=1)
        print(self.bij.forward_min_event_ndims)
        print('ldj', ldj)
        x = self.bij(x)
        
        #self.q = tfd.TransformedDistribution(
        #    distribution=tfd.MultivariateNormalDiag(loc=D*[0.]),
        #    bijector=self.bij
        #)
        #x = self.q.sample(N)
        return x
    
    def log_prob(self, x):
        return self.q.log_prob(x)

# %%
D = 2
num_layers = 2
num_units = 10 # units per layer
lr = 1e-1

dn = DensityNetwork(D, num_layers, num_units)
optimizer = tf.keras.optimizers.Adam(lr)

# %%
def gaussian_eta(mu, Sigma):
    n = mu.shape[0]
    Sigma_inv = np.linalg.inv(Sigma)
    x = np.dot(Sigma_inv, mu)
    y = np.reshape(-0.5*Sigma_inv, (n**2))
    eta = np.concatenate((x[:,0], y), 
                         axis=0)
    return eta


N = 100
mu = np.array([[10.0], [10.0]])
Sigma = np.eye(2)

@tf.function
def train_step():
    n = mu.shape[0]
    eta = gaussian_eta(mu, Sigma)
    with tf.GradientTape() as tape:
        x = dn(N)
        xl = x[:,:,tf.newaxis]
        xr = x[:,tf.newaxis,:]
        xxT = tf.matmul(xl, xr)
        xxT_vec = tf.reshape(xxT, (N,n**2))
        T_x = tf.concat((x, xxT_vec), axis=1)
        E_T_x = tf.reduce_mean(T_x, axis=0)
        
        loss = - tf.reduce_sum(eta*E_T_x)
        #loss = tf.reduce_sum(tf.square(E_T_x[:2] - mu[:,0]))
    
    params = dn.trainable_variables
    gradients = tape.gradient(loss, params)
        
    optimizer.apply_gradients(zip(gradients, params))
    return loss

# %%
num_iters = 1000
for i in range(num_iters):
    start_time = time.time()
    loss = train_step()
    end_time = time.time()
    if (i % 100 == 0):
        print(i, loss, 'took %.4f seconds' % (end_time-start_time))
        x = dn(N)
        print(dn.trainable_variables)
        plt.figure()
        plt.scatter(x[:,0], x[:,1]) #, c=dn.log_prob(x))
        plt.show()
# Out:
# ldj Tensor("affine_1/forward_log_det_jacobian/Neg_1:0", shape=(), dtype=float32)
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss.
# ldj Tensor("affine_1/forward_log_det_jacobian/Neg_1:0", shape=(), dtype=float32)
# WARNING:tensorflow:Gradients do not exist for variables ['Variable:0'] when minimizing the loss.
# 0 tf.Tensor(3.6653738, shape=(), dtype=float32) took 0.5410 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[0.09999998, 0.09999996]], dtype=float32)>]
# 100 tf.Tensor(-89.47803, shape=(), dtype=float32) took 0.0003 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[7.7826204, 7.779852 ]], dtype=float32)>]
# 200 tf.Tensor(-95.92093, shape=(), dtype=float32) took 0.0003 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[9.849695, 9.878833]], dtype=float32)>]
# 300 tf.Tensor(-95.84895, shape=(), dtype=float32) took 0.0003 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[9.976566, 9.999897]], dtype=float32)>]
# 400 tf.Tensor(-96.08284, shape=(), dtype=float32) took 0.0003 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[10.024144,  9.991025]], dtype=float32)>]
# 500 tf.Tensor(-96.30452, shape=(), dtype=float32) took 0.0003 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[10.029297, 10.02558 ]], dtype=float32)>]
# 600 tf.Tensor(-96.445526, shape=(), dtype=float32) took 0.0002 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[9.996234, 9.995996]], dtype=float32)>]
# 700 tf.Tensor(-95.14526, shape=(), dtype=float32) took 0.0002 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[10.041271,  9.995423]], dtype=float32)>]
# 800 tf.Tensor(-94.92203, shape=(), dtype=float32) took 0.0003 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[ 9.9407425, 10.03628  ]], dtype=float32)>]
# 900 tf.Tensor(-96.343445, shape=(), dtype=float32) took 0.0003 seconds
# ldj tf.Tensor(1.3862944, shape=(), dtype=float32)
# [<tf.Variable 'Variable:0' shape=(2, 2) dtype=float32, numpy=
# array([[1., 1.],
#        [1., 1.]], dtype=float32)>, <tf.Variable 'Variable:0' shape=(1, 2) dtype=float32, numpy=array([[9.997592, 9.978787]], dtype=float32)>]
